# %% [markdown]
# <a href="https://colab.research.google.com/github/oldairjsilva/IGTI/blob/main/trabalho_pratico_modulo_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install haversine

# %%
from haversine import haversine

lyon = (45.7597, 4.8422) # (lat, lon)
paris = (48.8567, 2.3508)

haversine(lyon, paris)
#>> 392.2172595594006  # in kilometers
# Out:
# 392.2172595594006

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/airports - Copia- 2.csv')

# %%
df.head()
# Out:
#    Item                                      Airport        Cidade  \
# 0     1                               Goroka Airport        Goroka
# 1     2                               Madang Airport        Madang
# 2     3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3     4                               Nadzab Airport        Nadzab
# 4     5  Port Moresby Jacksons International Airport  Port Moresby
#
#                Pais Sigla Sigla2  Latitude   Longitude   cod cod1 cod2  \
# 0  Papua New Guinea   GKA   AYGA -6.081690  145.391998  5282   10    U
# 1  Papua New Guinea   MAG   AYMD -5.207080  145.789001    20   10    U
# 2  Papua New Guinea   HGU   AYMH -5.826790  144.296005  5388   10    U
# 3  Papua New Guinea   LAE   AYNZ -6.569803  146.725977   239   10    U
# 4  Papua New Guinea   POM   AYPY -9.443380  147.220001   146   10    U
#
#                  Regiao     Tipo        Tipo2
# 0  Pacific/Port_Moresby  airport  OurAirports
# ...

# %%
df[(df["Airport"] == 'Amsterdam Airport Schiphol')][{'Latitude', 'Longitude'}]
# Out:
#      Longitude   Latitude
# 574    4.76389  52.308601

# %%
df[(df["Airport"] == 'Narita International Airport')][{'Latitude', 'Longitude'}]
# Out:
#        Longitude   Latitude
# 2181  140.386002  35.764702

# %%
from haversine import haversine

Amsterdam = (4.76389, 52.308601) # (lat, lon)
Narita = (140.386002, 35.764702)

haversine(Amsterdam, Narita)
#>> 392.2172595594006  # in kilometers
# Out:
# 14797.3404620775

# %%
df[(df["Airport"] == 'Jorge Newbery Airpark')][{'Latitude', 'Longitude'}]
# Out:
#       Longitude  Latitude
# 2320   -58.4156  -34.5592

# %%
df[(df["Airport"] == 'Guarulhos - Governador André Franco Montoro International Airport')][{'Latitude', 'Longitude'}]
# Out:
#       Longitude   Latitude
# 2436 -46.473057 -23.435556

# %%
from haversine import haversine

lyon = (-34.5592, -58.4156	) # (lat, lon)
paris = (-23.435556, -46.473057)

haversine(lyon, paris)
# Out:
# 1693.9996279229154

# %%
df[(df["Cidade"] == 'Sao Paulo')][{'Airport'}]
# Out:
#                                                 Airport
# 2436  Guarulhos - Governador André Franco Montoro In...
# 2464                             Campo de Marte Airport
# 2486                                  Congonhas Airport

# %%
df[(df["Pais"] == 'Brazil')][{'Airport'}]
# Out:
#                                    Airport
# 2392         Conceição do Araguaia Airport
# 2393  Campo Délio Jardim de Mattos Airport
# 2394                         Amapá Airport
# 2395                    Araraquara Airport
# 2396                   Santa Maria Airport
# ...                                    ...
# 7643                Augusto Severo Airport
# 7647                        Flores Airport
# 7659               Fazenda Uiapuru Airport
# 7670              Fazenda Kajussol Airport
# 7672                 Costa Marques Airport
#
# [264 rows x 1 columns]

# %%
df[(df["Cidade"] == 'London')][{'Airport', 'Cidade', 'Pais'}]
# Out:
#       Cidade                            Airport            Pais
# 172   London                     London Airport          Canada
# 487   London               London Luton Airport  United Kingdom
# 497   London             London Gatwick Airport  United Kingdom
# 498   London                London City Airport  United Kingdom
# 502   London            London Heathrow Airport  United Kingdom
# 542   London            London Stansted Airport  United Kingdom
# 5766  London                    London Heliport  United Kingdom
# 6141  London  London-Corbin Airport/Magee Field   United States
# 6759  London             Madison County Airport   United States

# %%
df[(df["Cidade"] == 'New York')][{'Airport', 'Cidade', 'Pais'}]
# Out:
#         Cidade                               Airport           Pais
# 3497  New York                    La Guardia Airport  United States
# 3597  New York  John F Kennedy International Airport  United States
# 3782  New York   Downtown-Manhattan/Wall St Heliport  United States
# 5773  New York                West 30th St. Heliport  United States
# 5779  New York           Indianola Municipal Airport  United States
# 5970  New York             One Police Plaza Heliport  United States

# %%
df[(df["Cidade"] == 'Rio de Janeiro')][{'Airport', 'Pais'}]
# Out:
#                                     Airport    Pais
# 6790                 Morro da Urca Heliport  Brazil
# 7306  Jacarepaguá - Roberto Marinho Airport  Brazil

# %%
df[(df["Pais"] == 'United States')][{'Airport', 'Cidade', 'Pais'}]
# Out:
#                Cidade                                   Airport           Pais
# 3212    Barter Island                Barter Island LRRS Airport  United States
# 3213  Fort Wainwright                    Wainwright Air Station  United States
# 3214    Cape Lisburne                Cape Lisburne LRRS Airport  United States
# 3215        Point Lay                    Point Lay LRRS Airport  United States
# 3216             Hilo                Hilo International Airport  United States
# ...               ...                                       ...            ...
# 7637        Oceanside  Camp Pendleton MCAS (Munn Field) Airport  United States
# 7651          Vidalia                  Vidalia Regional Airport  United States
# 7652         Granbury                 Granbury Regional Airport  United States
# 7653           Fulton                     Oswego County Airport  United States
# 7665         Mitchell                Mitchell Municipal Airport  United States
#
# [1512 rows x 3 columns]

# %%
df[(df["Pais"] == 'France')][{'Airport', 'Cidade', 'Pais'}]
# Out:
#                      Cidade                              Airport    Pais
# 1219                 Calais             Calais-Dunkerque Airport  France
# 1220                Peronne        Péronne-Saint-Quentin Airport  France
# 1221                 Nangis             Nangis-Les Loges Airport  France
# 1222      Bagnole-de-l'orne  Bagnoles-de-l'Orne-Couterne Airport  France
# 1223                 Albert                  Albert-Bray Airport  France
# ...                     ...                                  ...     ...
# 6883             Malbouhans             Lure Malbouhans Air Base  France
# 7118        Blois/Le Breuil              Blois-Le Breuil Airport  France
# 7329                 Lognes          Lognes Emerainville Airport  France
# 7487  Saint Pierre d'Oleron          St Pierre d'Oléron Airfield  France
# 7488        Semur en Auxois             Semur En Auxois Airfield  France
#
# [217 rows x 3 columns]

# %%
df[(df["Pais"] == 'Canada')][{'Airport', 'Cidade', 'Pais'}]
# Out:
#                   Cidade                            Airport    Pais
# 20    Sault Sainte Marie            Sault Ste Marie Airport  Canada
# 21              Winnipeg     Winnipeg / St. Andrews Airport  Canada
# 22               Halifax  Halifax / CFB Shearwater Heliport  Canada
# 23           St. Anthony                St. Anthony Airport  Canada
# 24                Tofino        Tofino / Long Beach Airport  Canada
# ...                  ...                                ...     ...
# 7506           Stratford        Stratford Municipal Airport  Canada
# 7507          Edmundston                 Edmundston Airport  Canada
# 7631           Lutselk'e                  Lutselk'e Airport  Canada
# 7660          Whitehorse           Whitehorse Seaplane Base  Canada
# 7671               Pelee               Pelee Island Airport  Canada
#
# [430 rows x 3 columns]

# %%
df["Pais"].nunique()
# Out:
# 237

# %%
df["Airport"].nunique()
# Out:
# 7658

# %%
media = df["Airport"].nunique() / df["Pais"].nunique()

# %%
media
# Out:
# 32.312236286919834

# %%
df.groupby("Pais").mean()
# Out:
#                        Item    Latitude    Longitude          cod
# Pais
# Afghanistan     5793.545455   34.037426    66.567935  4031.272727
# Albania         9734.400000   41.318320    19.822260   281.400000
# Algeria         1316.090909  518.135606    79.139269  1518.772727
# American Samoa  4798.500000  -14.274100  -170.067505    71.000000
# Angola          2910.800000  -10.789773    15.687952  2446.560000
# ...                     ...         ...          ...          ...
# West Bank       2174.000000   31.864700    35.219200  2485.000000
# Western Sahara  5670.333333   25.867266 -5318.967967   197.666667
# Yemen           4158.545455   14.931682  4531.783291  2088.727273
# Zambia          4654.769231   -9.630631    17.509054  3414.153846
# Zimbabwe        3207.500000  -18.439425    29.353270  3222.375000
#
# [237 rows x 4 columns]

# %%
df['cod'].mean()
# Out:
# 1015.873343725643
